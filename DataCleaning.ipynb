# %% [markdown]
# ## Data Extraction

# %%
import pandas as pd
import numpy as np
import datetime as dt
import os
import glob

# %%
jan = os.path.join("./Resources", 'JC-202101-citibike-tripdata.csv')
feb = os.path.join("./Resources", 'JC-202102-citibike-tripdata.csv')
mar = os.path.join("./Resources", 'JC-202103-citibike-tripdata.csv')
apr = os.path.join("./Resources", 'JC-202104-citibike-tripdata.csv')
may = os.path.join("./Resources", 'JC-202105-citibike-tripdata.csv')
jun = os.path.join("./Resources", 'JC-202106-citibike-tripdata.csv')
jul = os.path.join("./Resources", 'JC-202107-citibike-tripdata.csv')
aug = os.path.join("./Resources", 'JC-202108-citibike-tripdata.csv')
sep = os.path.join("./Resources", 'JC-202109-citibike-tripdata.csv')
octo = os.path.join("./Resources", 'JC-202110-citibike-tripdata.csv')
nov = os.path.join("./Resources", 'JC-202111-citibike-tripdata.csv')
dec = os.path.join("./Resources", 'JC-202112-citibike-tripdata.csv')

# %%
df1 = pd.read_csv(jan)
df2 = pd.read_csv(feb)
df3 = pd.read_csv(mar)
df4 = pd.read_csv(apr)
df5 = pd.read_csv(may)
df6 = pd.read_csv(jun)
df7 = pd.read_csv(jul)
df8 = pd.read_csv(aug)
df9 = pd.read_csv(sep)
df10 = pd.read_csv(octo)
df11 = pd.read_csv(nov)
df12 = pd.read_csv(dec)

# %%
#display df1 and df2 to show difference in column names
display(df1, df2)
# Out:
#        tripduration                 starttime                  stoptime  \
# 0               266  2021-01-01 00:03:35.5100  2021-01-01 00:08:01.7770
# 1              1543  2021-01-01 00:23:32.9250  2021-01-01 00:49:16.0830
# 2              1461  2021-01-01 00:23:50.7940  2021-01-01 00:48:12.5660
# 3               793  2021-01-01 00:31:09.0770  2021-01-01 00:44:22.9430
# 4               596  2021-01-01 00:35:52.1900  2021-01-01 00:45:48.7740
# ...             ...                       ...                       ...
# 11619          2476  2021-01-31 20:16:05.4700  2021-01-31 20:57:22.0110
# 11620           147  2021-01-31 21:05:05.2090  2021-01-31 21:07:32.8660
# 11621           660  2021-01-31 21:06:23.5880  2021-01-31 21:17:23.8420
# 11622           384  2021-01-31 21:16:37.8220  2021-01-31 21:23:02.1240
# 11623           356  2021-01-31 23:24:50.8810  2021-01-31 23:30:47.3030
#
#        start station id start station name  start station latitude  \
# ...

# %% [markdown]
# ## Data Preparation

# %%
# create a dictionary
# key = old name
# value = new name
dict = {'starttime': 'started_at',
        'stoptime': 'ended_at',
        'start station id': 'start_station_id',
        'start station name': 'start_station_name',
        'start station latitude': 'start_lat',
        'start station longitude': 'start_lng',
        'end station id': 'end_station_id',
        'end station name': 'end_station_name',
        'end station latitude': 'end_lat',
        'end station longitude': 'end_lng',
        'usertype': 'member_casual',
        'bikeid': 'ride_id'}

# call rename () method
df1.rename(columns=dict,
          inplace=True)
display(df1)
# Out:
#        tripduration                started_at                  ended_at  \
# 0               266  2021-01-01 00:03:35.5100  2021-01-01 00:08:01.7770
# 1              1543  2021-01-01 00:23:32.9250  2021-01-01 00:49:16.0830
# 2              1461  2021-01-01 00:23:50.7940  2021-01-01 00:48:12.5660
# 3               793  2021-01-01 00:31:09.0770  2021-01-01 00:44:22.9430
# 4               596  2021-01-01 00:35:52.1900  2021-01-01 00:45:48.7740
# ...             ...                       ...                       ...
# 11619          2476  2021-01-31 20:16:05.4700  2021-01-31 20:57:22.0110
# 11620           147  2021-01-31 21:05:05.2090  2021-01-31 21:07:32.8660
# 11621           660  2021-01-31 21:06:23.5880  2021-01-31 21:17:23.8420
# 11622           384  2021-01-31 21:16:37.8220  2021-01-31 21:23:02.1240
# 11623           356  2021-01-31 23:24:50.8810  2021-01-31 23:30:47.3030
#
#        start_station_id start_station_name  start_lat  start_lng  \
# ...

# %%
data_sets = [df1, df2, df3, df4, df5, df6, df7, df8, df9, df10, df11, df12]

# %%
combined_data = pd.concat(data_sets)
#reset index
#combined_data.reset_index()

# %%
combined_data
# Out:
#        tripduration                started_at                  ended_at  \
# 0             266.0  2021-01-01 00:03:35.5100  2021-01-01 00:08:01.7770
# 1            1543.0  2021-01-01 00:23:32.9250  2021-01-01 00:49:16.0830
# 2            1461.0  2021-01-01 00:23:50.7940  2021-01-01 00:48:12.5660
# 3             793.0  2021-01-01 00:31:09.0770  2021-01-01 00:44:22.9430
# 4             596.0  2021-01-01 00:35:52.1900  2021-01-01 00:45:48.7740
# ...             ...                       ...                       ...
# 48016           NaN       2021-12-16 16:15:22       2021-12-16 16:32:43
# 48017           NaN       2021-12-27 23:57:45       2021-12-28 00:00:23
# 48018           NaN       2021-12-21 13:32:14       2021-12-21 13:48:23
# 48019           NaN       2021-12-22 12:25:55       2021-12-22 12:34:17
# 48020           NaN       2021-12-17 17:31:22       2021-12-17 17:36:38
#
#       start_station_id start_station_name  start_lat  start_lng  \
# ...

# %%
combined_data.drop(columns=['birth year', 'gender'])
# Out:
#        tripduration                started_at                  ended_at  \
# 0             266.0  2021-01-01 00:03:35.5100  2021-01-01 00:08:01.7770
# 1            1543.0  2021-01-01 00:23:32.9250  2021-01-01 00:49:16.0830
# 2            1461.0  2021-01-01 00:23:50.7940  2021-01-01 00:48:12.5660
# 3             793.0  2021-01-01 00:31:09.0770  2021-01-01 00:44:22.9430
# 4             596.0  2021-01-01 00:35:52.1900  2021-01-01 00:45:48.7740
# ...             ...                       ...                       ...
# 48016           NaN       2021-12-16 16:15:22       2021-12-16 16:32:43
# 48017           NaN       2021-12-27 23:57:45       2021-12-28 00:00:23
# 48018           NaN       2021-12-21 13:32:14       2021-12-21 13:48:23
# 48019           NaN       2021-12-22 12:25:55       2021-12-22 12:34:17
# 48020           NaN       2021-12-17 17:31:22       2021-12-17 17:36:38
#
#       start_station_id start_station_name  start_lat  start_lng  \
# ...

# %% [markdown]
# ## Data Transformation

# %%
#save to new csv file to use for visualizations in Tableau

combined_data.to_csv('citibike_data.csv', index=False)
